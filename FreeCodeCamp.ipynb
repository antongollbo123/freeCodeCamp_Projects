# %% [markdown]
# # FreeCodeCamp - Data analysis with Python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)

# %% [markdown]
# # Mean-Variance-Standard Deviation Calculator

# %%
A = np.array([
    ['a', 'b', 'c'],
    ['d', 'e', 'f'],
    ['g', 'h', 'i']
])

print(A[:, :2])
# Out:
# [['a' 'b']
#  ['d' 'e']
#  ['g' 'h']]

# %%
s = pd.Series([1, 1, 2,3])
s.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2020.html"
nba_tables = pd.read_html(html_url)
nba = nba_tables[0]
nba.head()
# Out:
#   Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0   Milwaukee Bucks*  56  17  0.767     —  118.7  108.6  9.41
# 1   Toronto Raptors*  53  19  0.736   2.5  112.8  106.5  5.97
# 2    Boston Celtics*  48  24  0.667   7.5  113.7  107.3  5.83
# 3    Indiana Pacers*  45  28  0.616  11.0  109.4  107.5  1.63
# 4        Miami Heat*  44  29  0.603  12.0  112.0  109.1  2.59

# %%
import numpy as np

def calculate(list):
    if(len(list) == 9):
        list1 = list[0:3]
        list2 = list[3:6]
        list3 = list[6:9]
        matrix = np.matrix([list1,list2,list3])
        
        mean_cols = np.mean(matrix, 0)
        mean_cols = mean_cols.tolist()
        mean_rows = np.mean(matrix,1)
        mean_rows = mean_rows.flatten().tolist()
        mean_matrix = np.mean(matrix)
        
        var_cols = np.var(matrix,0)
        var_cols = var_cols.tolist()
        var_rows = np.var(matrix,1)
        var_rows = var_rows.flatten().tolist()
        var_matrix = np.var(matrix)
        
        std_cols = np.std(matrix,0)
        std_cols = std_cols.tolist()
        std_rows = np.std(matrix,1)
        std_rows = std_rows.flatten().tolist()
        std_matrix = np.std(matrix)
        
        max_cols = np.max(matrix,0)
        max_cols = max_cols.tolist()
        max_rows = np.max(matrix,1)
        max_rows = max_rows.flatten().tolist()
        max_matrix = np.max(matrix)
        
        min_cols = np.min(matrix,0)
        min_cols = min_cols.tolist()
        min_rows = np.min(matrix,1)
        min_rows = min_rows.flatten().tolist()
        min_matrix = np.min(matrix)
        
        sum_cols = np.sum(matrix,0)
        sum_cols = sum_cols.tolist()
        sum_rows = np.sum(matrix,1)
        sum_rows = sum_rows.flatten().tolist()
        sum_matrix = np.sum(matrix)
        
        

        calculations = {
            "mean": [mean_cols[0],mean_rows[0],mean_matrix],
            'variance': [var_cols[0], var_rows[0], var_matrix],
            'standard deviation': [std_cols[0], std_rows[0], std_matrix],
            'max': [max_cols[0], max_rows[0], max_matrix],
            'min': [min_cols[0], min_rows[0], min_matrix],
            'sum': [sum_cols[0], sum_rows[0], sum_matrix]

        }
        
    elif(len(list) != 9):
        raise ValueError("List must contain nine numbers.")
    return calculations
#expected = {'mean': [[3.6666666666666665, 5.0, 3.0], [3.3333333333333335, 4.0, 4.333333333333333], 3.888888888888889], 'variance': [[9.555555555555557, 0.6666666666666666, 8.666666666666666], [3.555555555555556, 10.666666666666666, 6.222222222222221], 6.987654320987654], 'standard deviation': [[3.091206165165235, 0.816496580927726, 2.943920288775949], [1.8856180831641267, 3.265986323710904, 2.494438257849294], 2.6434171674156266]
calculate([2,6,2,8,4,0,1,5,7])
# Out:
# {'mean': [[3.6666666666666665, 5.0, 3.0],
#   [3.3333333333333335, 4.0, 4.333333333333333],
#   3.888888888888889],
#  'variance': [[9.555555555555557, 0.6666666666666666, 8.666666666666666],
#   [3.555555555555556, 10.666666666666666, 6.222222222222221],
#   6.987654320987654],
#  'standard deviation': [[3.091206165165235,
#    0.816496580927726,
#    2.943920288775949],
#   [1.8856180831641267, 3.265986323710904, 2.494438257849294],
#   2.6434171674156266],
#  'max': [[8, 6, 7], [6, 8, 7], 8],
#  'min': [[1, 4, 0], [2, 0, 1], 0],
#  'sum': [[11, 15, 9], [10, 12, 13], 35]}

# %% [markdown]
# # Demographic Data Analyzer

# %%
df = pd.read_csv("demographic_data.csv")

#df.race.value_counts()

age_sex = df[["sex", "age"]]
males = age_sex[(age_sex["sex"]=="Male")]

average_age_men = round(np.mean(males.age),1)

# %%
no_of_bachelors = df[(df["education"] == "Bachelors" or "Masters" or "Postdoc")]
percentage_of_bachelors = round(no_of_bachelors.count()[0] / df.shape[0], 3)*100
percentage_of_bachelors = round(percentage_of_bachelors,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-36703bdfba9b> in <module>
# ----> 1 no_of_bachelors = df[(df["education"] == "Bachelors" or "Masters" or "Postdoc")]
#       2 percentage_of_bachelors = round(no_of_bachelors.count()[0] / df.shape[0], 3)*100
#       3 percentage_of_bachelors = round(percentage_of_bachelors,1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
no_of_advanced_education = df[(df["education"] == "Bachelors")]
no_of_advanced_education = no_of_advanced_education.append(df[(df["education"] == "Masters")])
no_of_advanced_education = no_of_advanced_education.append(df[(df["education"] == "Doctorate")])

no_of_advanced_education

no_of_advanced_education_salary = no_of_advanced_education[["education", "salary"]]
no_of_advanced_education_salary = no_of_advanced_education_salary[(no_of_advanced_education_salary["salary"] == ">50K")]
round(no_of_advanced_education_salary.shape[0] / no_of_advanced_education.shape[0],3)*100
# Out:
# 46.5

# %%
no_of_lower_education = df.drop(df[(df.education == "Bachelors") | (df.education == "Masters") | (df.education == "Doctorate")].index)

no_of_lower_education_salary = no_of_lower_education[(no_of_lower_education["salary"] == ">50K")]
round(no_of_lower_education_salary.shape[0] / no_of_lower_education.shape[0],3)*100
# Out:
# 17.4

# %%
lowest_hour_workers = df[(df["hours-per-week"] == 1)]

lhw_salary = lowest_hour_workers[(lowest_hour_workers["salary"] == ">50K")]

round(lhw_salary.shape[0] / lowest_hour_workers.shape[0],1)*100
# Out:
# 10.0

# %%
high_income = df[(df["salary"] == ">50K")]
high_income = high_income[["native-country", "salary"]]
values = high_income["native-country"].value_counts() / df["native-country"].value_counts()
highest_country_percentage = np.max(values)
highest_country = np.argmax(values)
highest_country
# Out:
# C:\Users\Anton\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:56: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return getattr(obj, method)(*args, **kwds)
# 'Iran'

# %%
india = df[(df["native-country"] == "India")]
india_salary = india[(india["salary"] == ">50K")]
value = np.argmax(india_salary["occupation"].value_counts())

# %%
value
# Out:
# 'Prof-specialty'

# %% [markdown]
# # Medical Data Analysis

# %%
df = pd.read_csv("medical_examination.csv")
overweight = [0] * len(df)
for i in range(len(df)):
    if (df.iloc[i].weight / (df.iloc[i].height / 100) ** 2) > 25:
        overweight[i] = 1
    elif (df.iloc[i].weight / (df.iloc[i].height / 100) ** 2) < 25:
        overweight[i] = 0

df["overweight"] = overweight

df.loc[df["cholesterol"] == 1, "cholesterol"] = 0      
df.loc[df['cholesterol'] > 1, "cholesterol"] = 1
df.loc[df["gluc"] == 1,"gluc"] = 0      
df.loc[df["gluc"] > 1,"gluc"] = 1

        

df_cat = pd.melt(df, value_vars=["active", "alco", "cholesterol", "gluc", "overweight", "smoke"], id_vars="cardio")

g = sns.catplot(data=df_cat, kind="count",  x="variable", hue="value", col="cardio")

# %%
g = sns.catplot(data=df_cat, kind="count",  x="variable", hue="value", col="cardio")
g.axes[0,0].set_ylabel('total')
fig = g.fig
fig.axes[0].get_xlabel()
# Out:
# 'variable'

# %%
fig.axes[0]

# %%
df = pd.read_csv('medical_examination.csv')
overweight = [0] * len(df)
for i in range(len(df)):
    if (df.iloc[i].weight / (df.iloc[i].height / 100) ** 2) > 25:
        overweight[i] = 1
    elif (df.iloc[i].weight / (df.iloc[i].height / 100) ** 2) < 25:
        overweight[i] = 0

df["overweight"] = overweight

df.loc[df["cholesterol"] == 1, "cholesterol"] = 0      
df.loc[df['cholesterol'] > 1, "cholesterol"] = 1
df.loc[df["gluc"] == 1,"gluc"] = 0      
df.loc[df["gluc"] > 1,"gluc"] = 1


df_clean = df[(df['ap_lo'] <= df['ap_hi'])]

df_clean = df_clean[(df_clean['height'] >= df_clean['height'].quantile(0.025))]
df_clean = df_clean[(df_clean['height'] <= df_clean['height'].quantile(0.975))]
df_clean = df_clean[(df_clean['weight'] >= df_clean['weight'].quantile(0.025))]
df_clean = df_clean[(df_clean['weight'] <= df_clean['weight'].quantile(0.975))]
fig, ax = plt.subplots(figsize=(10,10))
np.triu(np.ones_like(df_clean.corr()))
mask = np.triu(np.ones_like(df_clean.corr(), dtype=np.bool))

ax = sns.heatmap(round(df_clean.corr(),1), vmin=-0.1, vmax=0.28, annot=True, mask=mask,square=False,xticklabels=True, yticklabels=True, cbar_kws = {'shrink':0.5}, fmt='.1f');
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.0, 0.0)

# %%
df_clean = df[(df['ap_lo'] <= df['ap_hi']) & 
            (df['height'] >= df['height'].quantile(0.025)) &
            (df['height'] <= df['height'].quantile(0.975)) &
            (df['weight'] >= df['weight'].quantile(0.025)) & 
            (df['weight'] <= df['weight'].quantile(0.975))]

# Calculate the correlation matrix
corr = df_clean.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(df_clean.corr(), dtype=np.bool))

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the mask
sns.heatmap(corr, annot=True, fmt='.1f', mask=mask, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (14.0, 0.0)
